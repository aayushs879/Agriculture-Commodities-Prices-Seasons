# %%
#usual imports
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
print(os.listdir('../Social'))
# Out:
# ['filtered_Monthly_data.csv', 'Untitled.ipynb', 'CMO_MSP_Mandi.csv', 'Price Comparison.ipynb', 'Filter Outliers.ipynb', 'Seasonality_type.csv', 'filtered_cmo_mandi.csv', 'Deseasonalized_price.csv', 'Detect Seasonality type and deseasonalize prices.ipynb', '.ipynb_checkpoints', 'Monthly_data_cmo.csv']

# %%
#imoporting dataset
monthly = pd.read_csv('filtered_Monthly_data.csv')
print(monthly.head(10))
# Out:
#    Unnamed: 0        APMC      Commodity  Year  Month  arrivals_in_qtl  \
# 0           0  Ahmednagar          Bajri  2015  April               79
# 1           1  Ahmednagar          Bajri  2016  April              106
# 2           2  Ahmednagar  Wheat(Husked)  2015  April             1253
# 3           3  Ahmednagar  Wheat(Husked)  2016  April              387
# 4           4  Ahmednagar  Sorgum(Jawar)  2015  April             3825
# 5           5  Ahmednagar  Sorgum(Jawar)  2016  April             2093
# 6           6  Ahmednagar          Maize  2015  April               75
# 7           7  Ahmednagar          Maize  2016  April              155
# 8           8  Ahmednagar           Gram  2015  April             1794
# 9           9  Ahmednagar           Gram  2016  April              630
#
#    min_price  max_price  modal_price     date district_name   state_name
# 0       1406       1538         1463  2015-04    Ahmadnagar  Maharashtra
# 1       1788       1925         1875  2016-04    Ahmadnagar  Maharashtra
# 2       1572       1890         1731  2015-04    Ahmadnagar  Maharashtra
# 3       1750       2220         1999  2016-04    Ahmadnagar  Maharashtra
# 4       1600       2200         1900  2015-04    Ahmadnagar  Maharashtra
# 5       1695       2454         2119  2016-04    Ahmadnagar  Maharashtra
# 6       1345       1401         1373  2015-04    Ahmadnagar  Maharashtra
# 7       1367       1392         1375  2016-04    Ahmadnagar  Maharashtra
# 8       3533       3762         3647  2015-04    Ahmadnagar  Maharashtra
# 9       4790       5553         5216  2016-04    Ahmadnagar  Maharashtra

# %% [markdown]
# ### A Little Cleaning

# %%
monthly['date'] = pd.to_datetime(monthly['date']) # conversion to date time format
# making apmc-commodity clusters
monthly['cluster'] = monthly['APMC'] + '-' + monthly['Commodity']
#dropping modal prices having zero values as they can be a problem while creating the multiplicative model
monthly = monthly[monthly['modal_price'] != 0].reset_index(drop = True)
#dropping the extra index column which was added previously 
monthly = monthly.drop(['Unnamed: 0'], axis = 1)
print(monthly.columns)
# Out:
# Index(['APMC', 'Commodity', 'Year', 'Month', 'arrivals_in_qtl', 'min_price',
#        'max_price', 'modal_price', 'date', 'district_name', 'state_name',
#        'cluster'],
#       dtype='object')

# %% [markdown]
# ### Selecting those (APMC - Commodity) Clusters where we have data for at least a whole year and filtering the dataset accordingly

# %%
monthly_ = monthly[['APMC', 'Commodity', 'modal_price', 'Year', 'cluster']].groupby(['APMC', 'Commodity', 'Year', 'cluster'], as_index = False).count().rename(columns = {'modal_price':'count'}).reset_index(drop = True)

# %%
monthly_
# Out:
#              APMC              Commodity  Year  \
# 0         Aamgaon         PADDY-UNHUSKED  2016
# 1         Aamgaon         Paddy-Unhusked  2014
# 2         Aamgaon         Paddy-Unhusked  2015
# 3         Aamgaon         Paddy-Unhusked  2016
# 4           Aarni             Black Gram  2015
# 5           Aarni             Black Gram  2016
# 6           Aarni                   Gram  2014
# 7           Aarni                   Gram  2015
# 8           Aarni                   Gram  2016
# 9           Aarni             Green Gram  2015
# 10          Aarni             Green Gram  2016
# 11          Aarni  Ground Nut Pods (Dry)  2014
# 12          Aarni  Ground Nut Pods (Dry)  2015
# 13          Aarni  Ground Nut Pods (Dry)  2016
# 14          Aarni       Pigeon Pea (Tur)  2014
# 15          Aarni       Pigeon Pea (Tur)  2015
# 16          Aarni       Pigeon Pea (Tur)  2016
# 17          Aarni                SOYBEAN  2016
# 18          Aarni          Sorgum(Jawar)  2015
# 19          Aarni                Soybean  2014
# 20          Aarni                Soybean  2015
# 21          Aarni                Soybean  2016
# 22          Aarni          Wheat(Husked)  2014
# 23          Aarni          Wheat(Husked)  2015
# 24          Aarni          Wheat(Husked)  2016
# 25       Achalpur             BLACK GRAM  2016
# 26       Achalpur                  Bajri  2014
# 27       Achalpur                  Bajri  2015
# 28       Achalpur                  Bajri  2016
# 29       Achalpur                Batbati  2014
# ...           ...                    ...   ...
# 13284     Yeotmal                Sesamum  2015
# 13285     Yeotmal                Sesamum  2016
# 13286     Yeotmal          Sorgum(Jawar)  2014
# 13287     Yeotmal          Sorgum(Jawar)  2015
# 13288     Yeotmal          Sorgum(Jawar)  2016
# 13289     Yeotmal                Soybean  2014
# 13290     Yeotmal                Soybean  2015
# 13291     Yeotmal                Soybean  2016
# 13292     Yeotmal          WHEAT(HUSKED)  2016
# 13293     Yeotmal          Wheat(Husked)  2014
# 13294     Yeotmal          Wheat(Husked)  2015
# 13295     Yeotmal          Wheat(Husked)  2016
# 13296  Zarijamini                 COTTON  2016
# 13297  Zarijamini                 Cotton  2014
# 13298  Zarijamini                 Cotton  2015
# 13299  Zarijamini                 Cotton  2016
# 13300  Zarijamini                   Gram  2015
# 13301  Zarijamini                   Gram  2016
# 13302  Zarijamini             Green Gram  2016
# 13303  Zarijamini  Ground Nut Pods (Dry)  2015
# 13304  Zarijamini  Ground Nut Pods (Dry)  2016
# 13305  Zarijamini       Pigeon Pea (Tur)  2015
# 13306  Zarijamini       Pigeon Pea (Tur)  2016
# 13307  Zarijamini                SOYBEAN  2016
# 13308  Zarijamini          Sorgum(Jawar)  2015
# 13309  Zarijamini          Sorgum(Jawar)  2016
# 13310  Zarijamini                Soybean  2014
# 13311  Zarijamini                Soybean  2015
# 13312  Zarijamini                Soybean  2016
# 13313  Zarijamini          Wheat(Husked)  2015
#
#                                 cluster  count
# 0                Aamgaon-PADDY-UNHUSKED      1
# 1                Aamgaon-Paddy-Unhusked      4
# 2                Aamgaon-Paddy-Unhusked     12
# 3                Aamgaon-Paddy-Unhusked     10
# 4                      Aarni-Black Gram      1
# 5                      Aarni-Black Gram      2
# 6                            Aarni-Gram      2
# 7                            Aarni-Gram      6
# 8                            Aarni-Gram      5
# 9                      Aarni-Green Gram      2
# 10                     Aarni-Green Gram      1
# 11          Aarni-Ground Nut Pods (Dry)      2
# 12          Aarni-Ground Nut Pods (Dry)      2
# 13          Aarni-Ground Nut Pods (Dry)      5
# 14               Aarni-Pigeon Pea (Tur)      2
# 15               Aarni-Pigeon Pea (Tur)      8
# 16               Aarni-Pigeon Pea (Tur)     10
# 17                        Aarni-SOYBEAN      1
# 18                  Aarni-Sorgum(Jawar)      4
# 19                        Aarni-Soybean      4
# 20                        Aarni-Soybean     11
# 21                        Aarni-Soybean      7
# 22                  Aarni-Wheat(Husked)      2
# 23                  Aarni-Wheat(Husked)      5
# 24                  Aarni-Wheat(Husked)      1
# 25                  Achalpur-BLACK GRAM      1
# 26                       Achalpur-Bajri      1
# 27                       Achalpur-Bajri      1
# 28                       Achalpur-Bajri      3
# 29                     Achalpur-Batbati      1
# ...                                 ...    ...
# 13284                   Yeotmal-Sesamum      2
# 13285                   Yeotmal-Sesamum      1
# 13286             Yeotmal-Sorgum(Jawar)      2
# 13287             Yeotmal-Sorgum(Jawar)      4
# 13288             Yeotmal-Sorgum(Jawar)      4
# 13289                   Yeotmal-Soybean      4
# 13290                   Yeotmal-Soybean     12
# 13291                   Yeotmal-Soybean     10
# 13292             Yeotmal-WHEAT(HUSKED)      1
# 13293             Yeotmal-Wheat(Husked)      4
# 13294             Yeotmal-Wheat(Husked)     11
# 13295             Yeotmal-Wheat(Husked)      9
# 13296                 Zarijamini-COTTON      1
# 13297                 Zarijamini-Cotton      2
# 13298                 Zarijamini-Cotton      6
# 13299                 Zarijamini-Cotton      2
# 13300                   Zarijamini-Gram      3
# 13301                   Zarijamini-Gram      3
# 13302             Zarijamini-Green Gram      2
# 13303  Zarijamini-Ground Nut Pods (Dry)      2
# 13304  Zarijamini-Ground Nut Pods (Dry)      2
# 13305       Zarijamini-Pigeon Pea (Tur)      7
# 13306       Zarijamini-Pigeon Pea (Tur)      4
# 13307                Zarijamini-SOYBEAN      1
# 13308          Zarijamini-Sorgum(Jawar)      2
# 13309          Zarijamini-Sorgum(Jawar)      1
# 13310                Zarijamini-Soybean      2
# 13311                Zarijamini-Soybean      6
# 13312                Zarijamini-Soybean      5
# 13313          Zarijamini-Wheat(Husked)      1
#
# [13314 rows x 5 columns]

# %%
#dropping the columns where we dont have the data for a whole year
monthly_ = monthly_[monthly_['count'] == 12].reset_index(drop = True)

# %%
monthly_
# Out:
#                    APMC         Commodity  Year  \
# 0               Aamgaon    Paddy-Unhusked  2015
# 1         Akhadabalapur           Soybean  2015
# 2                 Akluj      Bitter Gourd  2015
# 3                 Akluj           Brinjal  2015
# 4                 Akluj           Cabbage  2015
# 5                 Akluj            Chikoo  2015
# 6                 Akluj     Chillies(Red)  2015
# 7                 Akluj     Ladies Finger  2015
# 8                 Akluj             Maize  2015
# 9                 Akluj             Onion  2015
# 10                Akluj            Potato  2015
# 11                Akluj            Shevga  2015
# 12                Akluj            Tomato  2015
# 13                Akluj       Water Melon  2015
# 14                Akole             Bajri  2015
# 15                Akole              Gram  2015
# 16                Akole    Paddy-Unhusked  2015
# 17                Akole           Soybean  2015
# 18                Akole     Wheat(Husked)  2015
# 19               Alibag   Rice(Paddy-Hus)  2015
# 20            Amarawati        Black Gram  2015
# 21            Amarawati        Green Gram  2015
# 22            Amarawati     Sorgum(Jawar)  2015
# 23            Amarawati           Soybean  2015
# 24            Amarawati     Wheat(Husked)  2015
# 25            Ambejogai              Gram  2015
# 26            Ambejogai  Pigeon Pea (Tur)  2015
# 27            Ambejogai           Soybean  2015
# 28      Anajngaon Surji            Banana  2015
# 29      Anajngaon Surji              Gram  2015
# ..                  ...               ...   ...
# 825        Vadgaon Peth       Ridge Gourd  2015
# 826        Vadgaon Peth            Tomato  2015
# 827               Vaduj              Gram  2015
# 828               Vaduj             Maize  2015
# 829               Vaduj     Sorgum(Jawar)  2015
# 830                 Vai      Bottle Gourd  2015
# 831                 Vai           Brinjal  2015
# 832                 Vai           Cabbage  2015
# 833                 Vai          Cucumber  2015
# 834                 Vai            Flower  2015
# 835                 Vai    Ginger (Fresh)  2015
# 836                 Vai      Green Chilli  2015
# 837                 Vai     Ladies Finger  2015
# 838                 Vai            Pavata  2015
# 839                 Vai            Tomato  2015
# 840  Varud-Rajura Bazar              Gram  2015
# 841  Varud-Rajura Bazar     Sorgum(Jawar)  2015
# 842  Varud-Rajura Bazar           Soybean  2015
# 843              Washim        Black Gram  2015
# 844              Washim              Gram  2015
# 845              Washim        Green Gram  2015
# 846              Washim  Pigeon Pea (Tur)  2015
# 847              Washim     Sorgum(Jawar)  2015
# 848              Washim     Wheat(Husked)  2015
# 849               Yeola             Bajri  2015
# 850               Yeola              Gram  2015
# 851               Yeola             Maize  2015
# 852               Yeola     Wheat(Husked)  2015
# 853             Yeotmal  Pigeon Pea (Tur)  2015
# 854             Yeotmal           Soybean  2015
#
#                               cluster  count
# 0              Aamgaon-Paddy-Unhusked     12
# 1               Akhadabalapur-Soybean     12
# 2                  Akluj-Bitter Gourd     12
# 3                       Akluj-Brinjal     12
# 4                       Akluj-Cabbage     12
# 5                        Akluj-Chikoo     12
# 6                 Akluj-Chillies(Red)     12
# 7                 Akluj-Ladies Finger     12
# 8                         Akluj-Maize     12
# 9                         Akluj-Onion     12
# 10                       Akluj-Potato     12
# 11                       Akluj-Shevga     12
# 12                       Akluj-Tomato     12
# 13                  Akluj-Water Melon     12
# 14                        Akole-Bajri     12
# 15                         Akole-Gram     12
# 16               Akole-Paddy-Unhusked     12
# 17                      Akole-Soybean     12
# 18                Akole-Wheat(Husked)     12
# 19             Alibag-Rice(Paddy-Hus)     12
# 20               Amarawati-Black Gram     12
# 21               Amarawati-Green Gram     12
# 22            Amarawati-Sorgum(Jawar)     12
# 23                  Amarawati-Soybean     12
# 24            Amarawati-Wheat(Husked)     12
# 25                     Ambejogai-Gram     12
# 26         Ambejogai-Pigeon Pea (Tur)     12
# 27                  Ambejogai-Soybean     12
# 28             Anajngaon Surji-Banana     12
# 29               Anajngaon Surji-Gram     12
# ..                                ...    ...
# 825          Vadgaon Peth-Ridge Gourd     12
# 826               Vadgaon Peth-Tomato     12
# 827                        Vaduj-Gram     12
# 828                       Vaduj-Maize     12
# 829               Vaduj-Sorgum(Jawar)     12
# 830                  Vai-Bottle Gourd     12
# 831                       Vai-Brinjal     12
# 832                       Vai-Cabbage     12
# 833                      Vai-Cucumber     12
# 834                        Vai-Flower     12
# 835                Vai-Ginger (Fresh)     12
# 836                  Vai-Green Chilli     12
# 837                 Vai-Ladies Finger     12
# 838                        Vai-Pavata     12
# 839                        Vai-Tomato     12
# 840           Varud-Rajura Bazar-Gram     12
# 841  Varud-Rajura Bazar-Sorgum(Jawar)     12
# 842        Varud-Rajura Bazar-Soybean     12
# 843                 Washim-Black Gram     12
# 844                       Washim-Gram     12
# 845                 Washim-Green Gram     12
# 846           Washim-Pigeon Pea (Tur)     12
# 847              Washim-Sorgum(Jawar)     12
# 848              Washim-Wheat(Husked)     12
# 849                       Yeola-Bajri     12
# 850                        Yeola-Gram     12
# 851                       Yeola-Maize     12
# 852               Yeola-Wheat(Husked)     12
# 853          Yeotmal-Pigeon Pea (Tur)     12
# 854                   Yeotmal-Soybean     12
#
# [855 rows x 5 columns]

# %%
# Now cleaning the data to have only those cleaned values as described previously
cluster_unique  = monthly_['cluster'].unique().tolist()
monthly = monthly[monthly['cluster'].isin(cluster_unique)].reset_index(drop = True)

# %%
monthly.to_csv('cleaned_monthly_data.csv', index = None)
print(monthly)
# Out:
#                  APMC         Commodity  Year      Month  arrivals_in_qtl  \
# 0               Akole             Bajri  2015      April               52
# 1               Akole             Bajri  2016      April               75
# 2               Akole    Paddy-Unhusked  2015      April              113
# 3               Akole    Paddy-Unhusked  2016      April              448
# 4               Akole     Wheat(Husked)  2015      April              164
# 5               Akole     Wheat(Husked)  2016      April              115
# 6               Akole              Gram  2015      April               39
# 7               Akole              Gram  2016      April               70
# 8               Akole           Soybean  2015      April              285
# 9               Akole           Soybean  2016      April              378
# 10            Jamkhed             Bajri  2015      April              164
# 11            Jamkhed             Bajri  2016      April               45
# 12            Jamkhed     Wheat(Husked)  2015      April              735
# 13            Jamkhed     Wheat(Husked)  2016      April               46
# 14            Jamkhed     Sorgum(Jawar)  2015      April            20890
# 15            Jamkhed     Sorgum(Jawar)  2016      April            24391
# 16            Jamkhed             Onion  2015      April             5232
# 17            Jamkhed             Onion  2016      April             7587
# 18          Kopargaon             Bajri  2015      April              354
# 19          Kopargaon             Bajri  2016      April              388
# 20          Kopargaon     Wheat(Husked)  2015      April             9668
# 21          Kopargaon     Wheat(Husked)  2016      April             1028
# 22          Kopargaon     Sorgum(Jawar)  2015      April              672
# 23          Kopargaon     Sorgum(Jawar)  2016      April             2038
# 24          Kopargaon             Maize  2015      April              389
# 25          Kopargaon             Maize  2016      April              284
# 26          Kopargaon              Gram  2015      April             2378
# 27          Kopargaon              Gram  2016      April              748
# 28          Kopargaon           Soybean  2015      April              329
# 29          Kopargaon           Soybean  2016      April              175
# ...               ...               ...   ...        ...              ...
# 21635          Digras     Wheat(Husked)  2014  September              488
# 21636          Digras     Wheat(Husked)  2015  September              413
# 21637          Digras     Wheat(Husked)  2016  September              616
# 21638          Digras              Gram  2014  September              188
# 21639          Digras              Gram  2015  September               34
# 21640          Digras              Gram  2016  September               27
# 21641          Digras  Pigeon Pea (Tur)  2014  September              148
# 21642          Digras  Pigeon Pea (Tur)  2015  September               24
# 21643          Digras  Pigeon Pea (Tur)  2016  September              441
# 21644          Digras           Soybean  2014  September               63
# 21645          Digras           Soybean  2015  September               59
# 21646          Digras           Soybean  2016  September              430
# 21647  Ner Parasopant           Soybean  2014  September              754
# 21648  Ner Parasopant           Soybean  2015  September             1803
# 21649  Ner Parasopant           Soybean  2016  September              525
# 21650        Umarkhed           Soybean  2014  September              100
# 21651        Umarkhed           Soybean  2015  September             1230
# 21652        Umarkhed           Soybean  2016  September              120
# 21653  Umarkhed-Danki     Wheat(Husked)  2014  September              500
# 21654  Umarkhed-Danki     Wheat(Husked)  2015  September              550
# 21655  Umarkhed-Danki     Wheat(Husked)  2016  September              770
# 21656  Umarkhed-Danki           Soybean  2014  September              100
# 21657  Umarkhed-Danki           Soybean  2015  September             1020
# 21658  Umarkhed-Danki           Soybean  2016  September              140
# 21659         Yeotmal  Pigeon Pea (Tur)  2014  September             1007
# 21660         Yeotmal  Pigeon Pea (Tur)  2015  September              319
# 21661         Yeotmal  Pigeon Pea (Tur)  2016  September             4830
# 21662         Yeotmal           Soybean  2014  September             2162
# 21663         Yeotmal           Soybean  2015  September             4797
# 21664         Yeotmal           Soybean  2016  September             3350
#
#        min_price  max_price  modal_price       date district_name  \
# 0           1357       1800         1525 2015-04-01    Ahmadnagar
# 1           1460       1960         1685 2016-04-01    Ahmadnagar
# 2           1450       1925         1625 2015-04-01    Ahmadnagar
# 3           1500       2017         1704 2016-04-01    Ahmadnagar
# 4           1450       1975         1644 2015-04-01    Ahmadnagar
# 5           1517       2150         1725 2016-04-01    Ahmadnagar
# 6           3200       3500         3350 2015-04-01    Ahmadnagar
# 7           3767       4833         4383 2016-04-01    Ahmadnagar
# 8           3000       3450         3250 2015-04-01    Ahmadnagar
# 9           3400       3883         3683 2016-04-01    Ahmadnagar
# 10          1304       1446         1375 2015-04-01    Ahmadnagar
# 11          1513       1742         1627 2016-04-01    Ahmadnagar
# 12          1856       2256         2056 2015-04-01    Ahmadnagar
# 13          2132       2268         2200 2016-04-01    Ahmadnagar
# 14          1800       2800         2300 2015-04-01    Ahmadnagar
# 15          1861       2933         2397 2016-04-01    Ahmadnagar
# 16           106       1469          788 2015-04-01    Ahmadnagar
# 17           100        939          519 2016-04-01    Ahmadnagar
# 18          1164       1469         1401 2015-04-01    Ahmadnagar
# 19          1603       2018         1750 2016-04-01    Ahmadnagar
# 20          1302       1713         1529 2015-04-01    Ahmadnagar
# 21          1486       1861         1652 2016-04-01    Ahmadnagar
# 22          1070       1421         1324 2015-04-01    Ahmadnagar
# 23          1445       1974         1770 2016-04-01    Ahmadnagar
# 24          1156       1257         1226 2015-04-01    Ahmadnagar
# 25          1373       1445         1418 2016-04-01    Ahmadnagar
# 26          3214       3822         3681 2015-04-01    Ahmadnagar
# 27          4492       5435         5276 2016-04-01    Ahmadnagar
# 28          3244       3590         3517 2015-04-01    Ahmadnagar
# 29          3728       3950         3893 2016-04-01    Ahmadnagar
# ...          ...        ...          ...        ...           ...
# 21635       1502       1315          572 2014-09-01      Yewatmal
# 21636       1534       1580         1551 2015-09-01      Yewatmal
# 21637       1719       1856         1774 2016-09-01      Yewatmal
# 21638       2223       2410         1615 2014-09-01      Yewatmal
# 21639       4016       4301         4203 2015-09-01      Yewatmal
# 21640       6317       6832         6414 2016-09-01      Yewatmal
# 21641       4495       4818         4338 2014-09-01      Yewatmal
# 21642       8780       9029         8951 2015-09-01      Yewatmal
# 21643       6576       6929         6765 2016-09-01      Yewatmal
# 21644       3176       1797         1170 2014-09-01      Yewatmal
# 21645       3097       3151         3133 2015-09-01      Yewatmal
# 21646       3140       3312         3254 2016-09-01      Yewatmal
# 21647       3255       3449         3351 2014-09-01      Yewatmal
# 21648       3104       3298         3202 2015-09-01      Yewatmal
# 21649       3161       3306         3233 2016-09-01      Yewatmal
# 21650       3000       3500         3300 2014-09-01      Yewatmal
# 21651       3150       3335         3255 2015-09-01      Yewatmal
# 21652       3300       3600         3500 2016-09-01      Yewatmal
# 21653       1433       1667         1533 2014-09-01      Yewatmal
# 21654       1380       1500         1440 2015-09-01      Yewatmal
# 21655       1500       1600         1550 2016-09-01      Yewatmal
# 21656       3000       3500         3300 2014-09-01      Yewatmal
# 21657       3164       3305         3241 2015-09-01      Yewatmal
# 21658       3450       3700         3600 2016-09-01      Yewatmal
# 21659       4345       4846         4599 2014-09-01      Yewatmal
# 21660       8222       9359         8752 2015-09-01      Yewatmal
# 21661       6141       6866         6476 2016-09-01      Yewatmal
# 21662       3063       3379         3225 2014-09-01      Yewatmal
# 21663       3064       3326         3218 2015-09-01      Yewatmal
# 21664       3046       3373         3224 2016-09-01      Yewatmal
#
#         state_name                       cluster
# 0      Maharashtra                   Akole-Bajri
# 1      Maharashtra                   Akole-Bajri
# 2      Maharashtra          Akole-Paddy-Unhusked
# 3      Maharashtra          Akole-Paddy-Unhusked
# 4      Maharashtra           Akole-Wheat(Husked)
# 5      Maharashtra           Akole-Wheat(Husked)
# 6      Maharashtra                    Akole-Gram
# 7      Maharashtra                    Akole-Gram
# 8      Maharashtra                 Akole-Soybean
# 9      Maharashtra                 Akole-Soybean
# 10     Maharashtra                 Jamkhed-Bajri
# 11     Maharashtra                 Jamkhed-Bajri
# 12     Maharashtra         Jamkhed-Wheat(Husked)
# 13     Maharashtra         Jamkhed-Wheat(Husked)
# 14     Maharashtra         Jamkhed-Sorgum(Jawar)
# 15     Maharashtra         Jamkhed-Sorgum(Jawar)
# 16     Maharashtra                 Jamkhed-Onion
# 17     Maharashtra                 Jamkhed-Onion
# 18     Maharashtra               Kopargaon-Bajri
# 19     Maharashtra               Kopargaon-Bajri
# 20     Maharashtra       Kopargaon-Wheat(Husked)
# 21     Maharashtra       Kopargaon-Wheat(Husked)
# 22     Maharashtra       Kopargaon-Sorgum(Jawar)
# 23     Maharashtra       Kopargaon-Sorgum(Jawar)
# 24     Maharashtra               Kopargaon-Maize
# 25     Maharashtra               Kopargaon-Maize
# 26     Maharashtra                Kopargaon-Gram
# 27     Maharashtra                Kopargaon-Gram
# 28     Maharashtra             Kopargaon-Soybean
# 29     Maharashtra             Kopargaon-Soybean
# ...            ...                           ...
# 21635  Maharashtra          Digras-Wheat(Husked)
# 21636  Maharashtra          Digras-Wheat(Husked)
# 21637  Maharashtra          Digras-Wheat(Husked)
# 21638  Maharashtra                   Digras-Gram
# 21639  Maharashtra                   Digras-Gram
# 21640  Maharashtra                   Digras-Gram
# 21641  Maharashtra       Digras-Pigeon Pea (Tur)
# 21642  Maharashtra       Digras-Pigeon Pea (Tur)
# 21643  Maharashtra       Digras-Pigeon Pea (Tur)
# 21644  Maharashtra                Digras-Soybean
# 21645  Maharashtra                Digras-Soybean
# 21646  Maharashtra                Digras-Soybean
# 21647  Maharashtra        Ner Parasopant-Soybean
# 21648  Maharashtra        Ner Parasopant-Soybean
# 21649  Maharashtra        Ner Parasopant-Soybean
# 21650  Maharashtra              Umarkhed-Soybean
# 21651  Maharashtra              Umarkhed-Soybean
# 21652  Maharashtra              Umarkhed-Soybean
# 21653  Maharashtra  Umarkhed-Danki-Wheat(Husked)
# 21654  Maharashtra  Umarkhed-Danki-Wheat(Husked)
# 21655  Maharashtra  Umarkhed-Danki-Wheat(Husked)
# 21656  Maharashtra        Umarkhed-Danki-Soybean
# 21657  Maharashtra        Umarkhed-Danki-Soybean
# 21658  Maharashtra        Umarkhed-Danki-Soybean
# 21659  Maharashtra      Yeotmal-Pigeon Pea (Tur)
# 21660  Maharashtra      Yeotmal-Pigeon Pea (Tur)
# 21661  Maharashtra      Yeotmal-Pigeon Pea (Tur)
# 21662  Maharashtra               Yeotmal-Soybean
# 21663  Maharashtra               Yeotmal-Soybean
# 21664  Maharashtra               Yeotmal-Soybean
#
# [21665 rows x 12 columns]

# %% [markdown]
# ### Now creating a function which first selects a particular (apmc-commodity) cluster then it decomposes the data according to both models (i.e a multiplicative and an additive model) then checks for the autocrrelation function of the residual part of the decomposition. The seasonality type corresponds to the model which gives the higher acf for the residual part. It also deseasonalizes the modal price according to the type of the seasonality a cluster follows

# %%
def check_seasonality(df, deseasonalize = False):
    df['period'] = df['Year'].astype('str') + df['Month']
    df['period'] = pd.to_datetime(df['period'], format = '%Y%B')
    
    #creating a temporary dataframe with modal price as values and months - year as indices
    tsdf = pd.DataFrame(data = df['modal_price'].values, index = df['period'], columns = ['modal_price'])
    tsdf.index = pd.to_datetime(tsdf.index)
    
    #resampling the data according to months
    tsdf = tsdf.resample('MS').mean()
    tsdf = tsdf.fillna(int(tsdf['modal_price'].mean())) #just a precaution so we dont get any missing values whatsoever
    
    #decomposition of the series according to both models
    result_add = seasonal_decompose(tsdf, model = 'additive', freq = 12)
    result_mul = seasonal_decompose(tsdf, model = 'multiplicative', freq = 12)
    
    # calculating autocorrelation function and accounting for less data in the except block
    try:
        additive_acf = sum(np.asarray(acf(result_add.resid, missing = 'drop'))*2)
        mult_acf = sum(np.asarray(acf(result_mul.resid, missing = 'drop'))*2)
        
    except:
        result_add = seasonal_decompose(tsdf, model='additive',freq=6)
        result_mul = seasonal_decompose(tsdf, model='multiplicative',freq=6)
        
        additive_acf=sum(np.asarray(acf(result_add.resid, missing='drop'))*2)
        mult_acf=sum(np.asarray(acf(result_mul.resid, missing='drop'))*2)
        
        
    if additive_acf < mult_acf:
        value = 'Additive'
        if deseasonalize:
            tsdf['Seasonal'] = result_add.seasonal.values # extracting the seasonal values
            values = tsdf['modal_price'] - tsdf['Seasonal'] # deseasonalization of price for additive model
            values = values.tolist()
            
            indices = df.index.tolist()
            values_range = range(0, len(values))
            for index, value in zip(indices, values_range):
                df.at[index, 'deseasonalize_price'] = values[value]
            return df[['APMC', 'Commodity', 'cluster', 'date', 'modal_price',  'deseasonalize_price']]
        else:
            return 'Additive'
        
        
    else:
        value = 'Multiplicative'
        if deseasonalize:
            tsdf['Seasonal'] = result_mul.seasonal.values
            values = tsdf['modal_price']/tsdf['Seasonal'] # deseasonalization of price for Multiplicative model
            values = values.tolist()
            
            indices = df.index.tolist()
            values_range = range(0, len(values))
            for index, value in zip(indices, values_range):
                df.at[index, 'deseasonalize_price'] = values[value]
            return df[['APMC', 'Commodity', 'cluster', 'date', 'modal_price', 'deseasonalize_price']]
        else:
            return 'Multiplicative'

# %% [markdown]
# ### now using the above made function to get seasonality type and getting the deseasonalized price

# %%
monthly['date'] = pd.to_datetime(monthly['date'])
i = 0 
seasonality = []
for cluster in cluster_unique:
    df = monthly[monthly['cluster'] == cluster]
    seasonality.append((cluster, check_seasonality(df)))
    i += 1
    if i % 200 == 0:
        print('completed upto index', i)
# Out:
# completed upto index 200
# completed upto index 400
# completed upto index 600
# completed upto index 800

# %%
seasonality
# Out:
# [('Aamgaon-Paddy-Unhusked', 'Multiplicative'),
#  ('Akhadabalapur-Soybean', 'Additive'),
#  ('Akluj-Bitter Gourd', 'Multiplicative'),
#  ('Akluj-Brinjal', 'Multiplicative'),
#  ('Akluj-Cabbage', 'Multiplicative'),
#  ('Akluj-Chikoo', 'Additive'),
#  ('Akluj-Chillies(Red)', 'Multiplicative'),
#  ('Akluj-Ladies Finger', 'Additive'),
#  ('Akluj-Maize', 'Additive'),
#  ('Akluj-Onion', 'Additive'),
#  ('Akluj-Potato', 'Additive'),
#  ('Akluj-Shevga', 'Additive'),
#  ('Akluj-Tomato', 'Multiplicative'),
#  ('Akluj-Water Melon', 'Multiplicative'),
#  ('Akole-Bajri', 'Multiplicative'),
#  ('Akole-Gram', 'Multiplicative'),
#  ('Akole-Paddy-Unhusked', 'Multiplicative'),
#  ('Akole-Soybean', 'Multiplicative'),
#  ('Akole-Wheat(Husked)', 'Additive'),
#  ('Alibag-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Amarawati-Black Gram', 'Additive'),
#  ('Amarawati-Green Gram', 'Additive'),
#  ('Amarawati-Sorgum(Jawar)', 'Additive'),
#  ('Amarawati-Soybean', 'Multiplicative'),
#  ('Amarawati-Wheat(Husked)', 'Additive'),
#  ('Ambejogai-Gram', 'Additive'),
#  ('Ambejogai-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Ambejogai-Soybean', 'Multiplicative'),
#  ('Anajngaon Surji-Banana', 'Multiplicative'),
#  ('Anajngaon Surji-Gram', 'Additive'),
#  ('Anajngaon Surji-Pigeon Pea (Tur)', 'Additive'),
#  ('Anajngaon Surji-Sorgum(Jawar)', 'Multiplicative'),
#  ('Anajngaon Surji-Soybean', 'Multiplicative'),
#  ('Anajngaon Surji-Wheat(Husked)', 'Multiplicative'),
#  ('Arjuni Morgaon-Paddy-Unhusked', 'Multiplicative'),
#  ('Armori-Paddy-Unhusked', 'Multiplicative'),
#  ('Armori-Desaiganj-Paddy-Unhusked', 'Multiplicative'),
#  ('Aurangabad-Bitter Gourd', 'Multiplicative'),
#  ('Aurangabad-Bottle Gourd', 'Multiplicative'),
#  ('Aurangabad-Brinjal', 'Multiplicative'),
#  ('Aurangabad-Cabbage', 'Additive'),
#  ('Aurangabad-Capsicum', 'Additive'),
#  ('Aurangabad-Cluster Bean', 'Additive'),
#  ('Aurangabad-Cucumber', 'Multiplicative'),
#  ('Aurangabad-Flower', 'Multiplicative'),
#  ('Aurangabad-Garlic', 'Multiplicative'),
#  ('Aurangabad-Ginger (Fresh)', 'Additive'),
#  ('Aurangabad-Green Chilli', 'Additive'),
#  ('Aurangabad-Ladies Finger', 'Additive'),
#  ('Aurangabad-Lemon', 'Multiplicative'),
#  ('Aurangabad-Mosambi', 'Multiplicative'),
#  ('Aurangabad-Onion', 'Additive'),
#  ('Aurangabad-Papai', 'Multiplicative'),
#  ('Aurangabad-Pomegranate', 'Additive'),
#  ('Aurangabad-Potato', 'Multiplicative'),
#  ('Aurangabad-Shevga', 'Multiplicative'),
#  ('Aurangabad-Tomato', 'Multiplicative'),
#  ('Ausa-Gram', 'Multiplicative'),
#  ('Ausa-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Ausa-Safflower', 'Multiplicative'),
#  ('Ausa-Sorgum(Jawar)', 'Additive'),
#  ('Ausa-Soybean', 'Multiplicative'),
#  ('Ausa-Sunflower', 'Multiplicative'),
#  ('Ausa-Wheat(Husked)', 'Multiplicative'),
#  ('Babhulgaon-Soybean', 'Additive'),
#  ('Balapur-Gram', 'Multiplicative'),
#  ('Balapur-Green Gram', 'Multiplicative'),
#  ('Balapur-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Balapur-Sorgum(Jawar)', 'Additive'),
#  ('Balapur-Soybean', 'Additive'),
#  ('Balapur-Wheat(Husked)', 'Additive'),
#  ('Barshi-Bajri', 'Multiplicative'),
#  ('Barshi-Bitter Gourd', 'Multiplicative'),
#  ('Barshi-Black Gram', 'Multiplicative'),
#  ('Barshi-Brinjal', 'Additive'),
#  ('Barshi-Cabbage', 'Multiplicative'),
#  ('Barshi-Capsicum', 'Additive'),
#  ('Barshi-Cluster Bean', 'Multiplicative'),
#  ('Barshi-Cucumber', 'Additive'),
#  ('Barshi-Flower', 'Multiplicative'),
#  ('Barshi-Fodder', 'Multiplicative'),
#  ('Barshi-Gram', 'Additive'),
#  ('Barshi-Green Chilli', 'Multiplicative'),
#  ('Barshi-Green Gram', 'Additive'),
#  ('Barshi-Ladies Finger', 'Multiplicative'),
#  ('Barshi-Lemon', 'Multiplicative'),
#  ('Barshi-Maize', 'Multiplicative'),
#  ('Barshi-Paddy-Unhusked', 'Multiplicative'),
#  ('Barshi-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Barshi-Ridge Gourd', 'Additive'),
#  ('Barshi-Sorgum(Jawar)', 'Multiplicative'),
#  ('Barshi-Tomato', 'Multiplicative'),
#  ('Barshi-Turmeric', 'Multiplicative'),
#  ('Barshi-Wheat(Husked)', 'Additive'),
#  ('Barshi-Vairag-Ground Nut Pods (Dry)', 'Additive'),
#  ('Barshi-Vairag-Sorgum(Jawar)', 'Multiplicative'),
#  ('Bhivandi-Onion', 'Additive'),
#  ('Bhivandi-Other Vegetables', 'Multiplicative'),
#  ('Bhivandi-Potato', 'Additive'),
#  ('Bhivandi-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Bhivandi-Wheat(Husked)', 'Additive'),
#  ('Bhiwapur-Chillies(Red)', 'Additive'),
#  ('Bhiwapur-Paddy-Unhusked', 'Multiplicative'),
#  ('Bhokar-Gram', 'Multiplicative'),
#  ('Bhokar-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Bhokar-Sesamum', 'Additive'),
#  ('Bhokar-Soybean', 'Additive'),
#  ('Bhokar-Turmeric', 'Multiplicative'),
#  ('Bhokar-Wheat(Husked)', 'Additive'),
#  ('Bhokardan-Maize', 'Multiplicative'),
#  ('Bhokardan-Sorgum(Jawar)', 'Additive'),
#  ('Bhokardan-Soybean', 'Additive'),
#  ('Bhokardan-Wheat(Husked)', 'Additive'),
#  ('Bhokardan-Pimpalgaon Renu-Maize', 'Additive'),
#  ('Bhokardan-Pimpalgaon Renu-Soybean', 'Multiplicative'),
#  ('Bhokardan-Pimpalgaon Renu-Wheat(Husked)', 'Additive'),
#  ('Bhusaval-Sorgum(Jawar)', 'Multiplicative'),
#  ('Bhusaval-Wheat(Husked)', 'Multiplicative'),
#  ('Buldhana-Gram', 'Multiplicative'),
#  ('Buldhana-Soybean', 'Additive'),
#  ('Chamorshi-Paddy-Unhusked', 'Additive'),
#  ('Chandur Bajar-Gram', 'Multiplicative'),
#  ('Chandur Bajar-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Chandur Bajar-Soybean', 'Multiplicative'),
#  ('Chandur Bajar-Wheat(Husked)', 'Multiplicative'),
#  ('Chopda-Bajri', 'Additive'),
#  ('Chopda-Gram', 'Additive'),
#  ('Chopda-Maize', 'Additive'),
#  ('Chopda-Sorgum(Jawar)', 'Additive'),
#  ('Chopda-Wheat(Husked)', 'Additive'),
#  ('Devala-Bajri', 'Multiplicative'),
#  ('Devala-Gram', 'Multiplicative'),
#  ('Devala-Maize', 'Multiplicative'),
#  ('Devala-Sorgum(Jawar)', 'Additive'),
#  ('Devala-Wheat(Husked)', 'Multiplicative'),
#  ('Dhule-Bajri', 'Multiplicative'),
#  ('Dhule-Chillies(Red)', 'Multiplicative'),
#  ('Dhule-Cowpea', 'Additive'),
#  ('Dhule-Gram', 'Additive'),
#  ('Dhule-Green Gram', 'Additive'),
#  ('Dhule-Ground Nut Pods (Dry)', 'Multiplicative'),
#  ('Dhule-Maize', 'Additive'),
#  ('Dhule-Matki', 'Multiplicative'),
#  ('Dhule-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Dhule-Sorgum(Jawar)', 'Multiplicative'),
#  ('Dhule-Soybean', 'Additive'),
#  ('Dhule-Wheat(Husked)', 'Multiplicative'),
#  ('Digras-Gram', 'Additive'),
#  ('Digras-Pigeon Pea (Tur)', 'Additive'),
#  ('Digras-Soybean', 'Additive'),
#  ('Digras-Wheat(Husked)', 'Additive'),
#  ('Dondaicha-Bajri', 'Multiplicative'),
#  ('Dondaicha-Gram', 'Multiplicative'),
#  ('Dondaicha-Ground Nut Pods (Dry)', 'Additive'),
#  ('Dondaicha-Maize', 'Additive'),
#  ('Dondaicha-Sorgum(Jawar)', 'Multiplicative'),
#  ('Dondaicha-Wheat(Husked)', 'Multiplicative'),
#  ('Dudhani-Gram', 'Multiplicative'),
#  ('Dudhani-Sorgum(Jawar)', 'Multiplicative'),
#  ('Dudhani-Wheat(Husked)', 'Additive'),
#  ('Gadchiroli-Paddy-Unhusked', 'Multiplicative'),
#  ('Gangapur-Bajri', 'Multiplicative'),
#  ('Gangapur-Gram', 'Additive'),
#  ('Gangapur-Maize', 'Additive'),
#  ('Gangapur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Gangapur-Wheat(Husked)', 'Additive'),
#  ('Gevrai-Bajri', 'Multiplicative'),
#  ('Gevrai-Gram', 'Multiplicative'),
#  ('Gevrai-Maize', 'Additive'),
#  ('Gevrai-Sorgum(Jawar)', 'Additive'),
#  ('Gevrai-Soybean', 'Additive'),
#  ('Gevrai-Wheat(Husked)', 'Multiplicative'),
#  ('Hinganghat-Gram', 'Multiplicative'),
#  ('Hingoli-Gram', 'Additive'),
#  ('Hingoli-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Hingoli-Soybean', 'Multiplicative'),
#  ('Indapur-Onion', 'Multiplicative'),
#  ('Jafrabad-Maize', 'Multiplicative'),
#  ('Jafrabad-Soybean', 'Additive'),
#  ('Jafrabad-Wheat(Husked)', 'Multiplicative'),
#  ('Jalgaon-Bajri', 'Multiplicative'),
#  ('Jalgaon-Banana', 'Multiplicative'),
#  ('Jalgaon-Bitter Gourd', 'Additive'),
#  ('Jalgaon-Brinjal', 'Additive'),
#  ('Jalgaon-Cabbage', 'Multiplicative'),
#  ('Jalgaon-Chavli (Shenga )', 'Additive'),
#  ('Jalgaon-Cluster Bean', 'Multiplicative'),
#  ('Jalgaon-Coriander  ', 'Multiplicative'),
#  ('Jalgaon-Cucumber', 'Additive'),
#  ('Jalgaon-Flower', 'Multiplicative'),
#  ('Jalgaon-Ginger (Fresh)', 'Multiplicative'),
#  ('Jalgaon-Gram', 'Multiplicative'),
#  ('Jalgaon-Green Chilli', 'Additive'),
#  ('Jalgaon-Jaggery', 'Multiplicative'),
#  ('Jalgaon-Ladies Finger', 'Multiplicative'),
#  ('Jalgaon-Lemon', 'Multiplicative'),
#  ('Jalgaon-Maize', 'Additive'),
#  ('Jalgaon-Methi (Bhaji)', 'Additive'),
#  ('Jalgaon-Mosambi', 'Multiplicative'),
#  ('Jalgaon-Onion', 'Additive'),
#  ('Jalgaon-Pomegranate', 'Multiplicative'),
#  ('Jalgaon-Potato', 'Multiplicative'),
#  ('Jalgaon-Sorgum(Jawar)', 'Additive'),
#  ('Jalgaon-Spinach', 'Multiplicative'),
#  ('Jalgaon-Tomato', 'Additive'),
#  ('Jalgaon-Wal Papdi', 'Multiplicative'),
#  ('Jalgaon-Wheat(Husked)', 'Multiplicative'),
#  ('Jalgaon Jamod-Maize', 'Multiplicative'),
#  ('Jalgaon Jamod-Soybean', 'Multiplicative'),
#  ('Jalgaon Jamod-Wheat(Husked)', 'Multiplicative'),
#  ('Jalgaon Jamod-Aasalgaon-Gram', 'Additive'),
#  ('Jalgaon Jamod-Aasalgaon-Maize', 'Additive'),
#  ('Jalgaon Jamod-Aasalgaon-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Jalgaon Jamod-Aasalgaon-Sorgum(Jawar)', 'Multiplicative'),
#  ('Jalgaon Jamod-Aasalgaon-Soybean', 'Additive'),
#  ('Jalgaon Jamod-Aasalgaon-Wheat(Husked)', 'Multiplicative'),
#  ('Jalna-Bajri', 'Additive'),
#  ('Jalna-Gram', 'Multiplicative'),
#  ('Jalna-Green Gram', 'Multiplicative'),
#  ('Jalna-Jaggery', 'Multiplicative'),
#  ('Jalna-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Jalna-Sorgum(Jawar)', 'Multiplicative'),
#  ('Jalna-Wheat(Husked)', 'Additive'),
#  ('Jamkhed-Bajri', 'Multiplicative'),
#  ('Jamkhed-Onion', 'Multiplicative'),
#  ('Jamkhed-Sorgum(Jawar)', 'Additive'),
#  ('Jamkhed-Wheat(Husked)', 'Multiplicative'),
#  ('Jintur-Sorgum(Jawar)', 'Additive'),
#  ('Jintur-Soybean', 'Multiplicative'),
#  ('Jintur-Wheat(Husked)', 'Multiplicative'),
#  ('Junnar-Onion', 'Additive'),
#  ('Kada-Bajri', 'Additive'),
#  ('Kada-Gram', 'Multiplicative'),
#  ('Kada-Maize', 'Multiplicative'),
#  ('Kada-Onion', 'Multiplicative'),
#  ('Kada-Sorgum(Jawar)', 'Additive'),
#  ('Kada-Wheat(Husked)', 'Additive'),
#  ('Kalamb (Os)-Bajri', 'Multiplicative'),
#  ('Kalamb (Os)-Gram', 'Multiplicative'),
#  ('Kalamb (Os)-Green Gram', 'Additive'),
#  ('Kalamb (Os)-Maize', 'Multiplicative'),
#  ('Kalamb (Os)-Pigeon Pea (Tur)', 'Additive'),
#  ('Kalamb (Os)-Safflower', 'Additive'),
#  ('Kalamb (Os)-Sesamum', 'Additive'),
#  ('Kalamb (Os)-Sorgum(Jawar)', 'Additive'),
#  ('Kalamb (Os)-Soybean', 'Multiplicative'),
#  ('Kalamb (Os)-Sunflower', 'Multiplicative'),
#  ('Kalamb (Os)-Wheat(Husked)', 'Additive'),
#  ('Kalamnuri-Wheat(Husked)', 'Multiplicative'),
#  ('Kalmeshwar-Brinjal', 'Multiplicative'),
#  ('Kalmeshwar-Coriander  ', 'Multiplicative'),
#  ('Kalmeshwar-Flower', 'Multiplicative'),
#  ('Kalmeshwar-Green Chilli', 'Multiplicative'),
#  ('Kalmeshwar-Spinach', 'Multiplicative'),
#  ('Kalmeshwar-Tomato', 'Multiplicative'),
#  ('Kalvan-Bajri', 'Multiplicative'),
#  ('Kalvan-Maize', 'Multiplicative'),
#  ('Kalvan-Soybean', 'Multiplicative'),
#  ('Kalvan-Wheat(Husked)', 'Multiplicative'),
#  ('Kamthi-Bitter Gourd', 'Additive'),
#  ('Kamthi-Bottle Gourd', 'Additive'),
#  ('Kamthi-Brinjal', 'Multiplicative'),
#  ('Kamthi-Cabbage', 'Multiplicative'),
#  ('Kamthi-Capsicum', 'Multiplicative'),
#  ('Kamthi-Chavli (Pala)', 'Multiplicative'),
#  ('Kamthi-Chavli (Shenga )', 'Multiplicative'),
#  ('Kamthi-Cluster Bean', 'Multiplicative'),
#  ('Kamthi-Coriander  ', 'Multiplicative'),
#  ('Kamthi-Cucumber', 'Multiplicative'),
#  ('Kamthi-Flower', 'Multiplicative'),
#  ('Kamthi-Ginger (Fresh)', 'Additive'),
#  ('Kamthi-Green Chilli', 'Multiplicative'),
#  ('Kamthi-Ladies Finger', 'Additive'),
#  ('Kamthi-Lemon', 'Multiplicative'),
#  ('Kamthi-Methi (Bhaji)', 'Multiplicative'),
#  ('Kamthi-Mint', 'Additive'),
#  ('Kamthi-Onion', 'Additive'),
#  ('Kamthi-Potato', 'Additive'),
#  ('Kamthi-Pumpkin', 'Additive'),
#  ('Kamthi-Raddish', 'Multiplicative'),
#  ('Kamthi-Small Gourd', 'Multiplicative'),
#  ('Kamthi-Spinach', 'Additive'),
#  ('Kamthi-Tomato', 'Additive'),
#  ('Karad-Banana', 'Multiplicative'),
#  ('Karad-Bitter Gourd', 'Multiplicative'),
#  ('Karad-Bottle Gourd', 'Multiplicative'),
#  ('Karad-Brinjal', 'Multiplicative'),
#  ('Karad-Cabbage', 'Multiplicative'),
#  ('Karad-Capsicum', 'Additive'),
#  ('Karad-Chikoo', 'Additive'),
#  ('Karad-Cluster Bean', 'Multiplicative'),
#  ('Karad-Cucumber', 'Multiplicative'),
#  ('Karad-Flower', 'Multiplicative'),
#  ('Karad-Garlic', 'Multiplicative'),
#  ('Karad-Ginger (Fresh)', 'Multiplicative'),
#  ('Karad-Green Chilli', 'Additive'),
#  ('Karad-Ladies Finger', 'Additive'),
#  ('Karad-Mosambi', 'Multiplicative'),
#  ('Karad-Onion', 'Multiplicative'),
#  ('Karad-Pavtta', 'Multiplicative'),
#  ('Karad-Pomegranate', 'Multiplicative'),
#  ('Karad-Potato', 'Additive'),
#  ('Karad-Ridge Gourd', 'Additive'),
#  ('Karad-Shevga', 'Additive'),
#  ('Karad-Tomato', 'Multiplicative'),
#  ('Karanja-Black Gram', 'Additive'),
#  ('Karanja-Gram', 'Additive'),
#  ('Karanja-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Karanja-Sorgum(Jawar)', 'Additive'),
#  ('Karanja-Wheat(Husked)', 'Multiplicative'),
#  ('Karjat (Raigad)-Paddy-Unhusked', 'Multiplicative'),
#  ('Karjat (Raigad)-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Katol-Gram', 'Multiplicative'),
#  ('Katol-Ground Nut Pods (Dry)', 'Multiplicative'),
#  ('Katol-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Katol-Soybean', 'Multiplicative'),
#  ('Katol-Wheat(Husked)', 'Multiplicative'),
#  ('Kille Dharur-Bajri', 'Additive'),
#  ('Kille Dharur-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Kille Dharur-Sorgum(Jawar)', 'Additive'),
#  ('Kille Dharur-Soybean', 'Additive'),
#  ('Kille Dharur-Wheat(Husked)', 'Additive'),
#  ('Kopargaon-Bajri', 'Additive'),
#  ('Kopargaon-Gram', 'Multiplicative'),
#  ('Kopargaon-Maize', 'Additive'),
#  ('Kopargaon-Onion', 'Additive'),
#  ('Kopargaon-Sorgum(Jawar)', 'Multiplicative'),
#  ('Kopargaon-Soybean', 'Additive'),
#  ('Kopargaon-Wheat(Husked)', 'Additive'),
#  ('Koregaon-Ghevda Seed', 'Multiplicative'),
#  ('Koregaon-Gram', 'Additive'),
#  ('Koregaon-Onion', 'Additive'),
#  ('Kurdwadi-Maize', 'Additive'),
#  ('Kurdwadi-Sorgum(Jawar)', 'Multiplicative'),
#  ('Kurdwadi-Wheat(Husked)', 'Multiplicative'),
#  ('Kurdwadi-Modnimb-Gram', 'Additive'),
#  ('Kurdwadi-Modnimb-Maize', 'Multiplicative'),
#  ('Kurdwadi-Modnimb-Sorgum(Jawar)', 'Additive'),
#  ('Kurdwadi-Modnimb-Wheat(Husked)', 'Additive'),
#  ('Lasalgaon-Bajri', 'Multiplicative'),
#  ('Lasalgaon-Gram', 'Multiplicative'),
#  ('Lasalgaon-Maize', 'Multiplicative'),
#  ('Lasalgaon-Sorgum(Jawar)', 'Additive'),
#  ('Lasalgaon-Soybean', 'Multiplicative'),
#  ('Lasalgaon-Wheat(Husked)', 'Additive'),
#  ('Lasur Station-Bajri', 'Multiplicative'),
#  ('Lasur Station-Gram', 'Additive'),
#  ('Lasur Station-Maize', 'Multiplicative'),
#  ('Lasur Station-Onion', 'Additive'),
#  ('Lasur Station-Sorgum(Jawar)', 'Additive'),
#  ('Lasur Station-Soybean', 'Additive'),
#  ('Lasur Station-Wheat(Husked)', 'Additive'),
#  ('Latur-Gram', 'Multiplicative'),
#  ('Latur-Green Gram', 'Additive'),
#  ('Latur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Latur-Wheat(Husked)', 'Multiplicative'),
#  ('Lonand-Bajri', 'Additive'),
#  ('Lonand-Gram', 'Multiplicative'),
#  ('Lonand-Maize', 'Multiplicative'),
#  ('Lonand-Onion', 'Multiplicative'),
#  ('Lonand-Sorgum(Jawar)', 'Multiplicative'),
#  ('Lonand-Wheat(Husked)', 'Multiplicative'),
#  ('Lonar-Gram', 'Multiplicative'),
#  ('Lonar-Soybean', 'Additive'),
#  ('Lonar-Wheat(Husked)', 'Multiplicative'),
#  ('Majalgaon-Bajri', 'Multiplicative'),
#  ('Majalgaon-Gram', 'Multiplicative'),
#  ('Majalgaon-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Majalgaon-Sorgum(Jawar)', 'Multiplicative'),
#  ('Majalgaon-Soybean', 'Multiplicative'),
#  ('Majalgaon-Wheat(Husked)', 'Additive'),
#  ('Malegaon-Bajri', 'Additive'),
#  ('Malegaon-Maize', 'Additive'),
#  ('Malegaon-Wheat(Husked)', 'Multiplicative'),
#  ('Malkapur-Bajri', 'Additive'),
#  ('Malkapur-Black Gram', 'Multiplicative'),
#  ('Malkapur-Gram', 'Multiplicative'),
#  ('Malkapur-Green Gram', 'Additive'),
#  ('Malkapur-Maize', 'Multiplicative'),
#  ('Malkapur-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Malkapur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Malkapur-Soybean', 'Multiplicative'),
#  ('Malkapur-Wheat(Husked)', 'Multiplicative'),
#  ('Mandhal-Chillies(Red)', 'Multiplicative'),
#  ('Mandhal-Soybean', 'Additive'),
#  ('Mangalwedha-Bitter Gourd', 'Multiplicative'),
#  ('Mangalwedha-Brinjal', 'Additive'),
#  ('Mangalwedha-Cucumber', 'Multiplicative'),
#  ('Mangalwedha-Gram', 'Multiplicative'),
#  ('Mangalwedha-Green Chilli', 'Multiplicative'),
#  ('Mangalwedha-Ladies Finger', 'Multiplicative'),
#  ('Mangalwedha-Maize', 'Additive'),
#  ('Mangalwedha-Ridge Gourd', 'Multiplicative'),
#  ('Mangalwedha-Sorgum(Jawar)', 'Multiplicative'),
#  ('Mangalwedha-Tomato', 'Multiplicative'),
#  ('Mangalwedha-Wheat(Husked)', 'Additive'),
#  ('Mangaon(Bhadav)-Nachani', 'Additive'),
#  ('Mangaon(Bhadav)-Nagali', 'Multiplicative'),
#  ('Mangaon(Bhadav)-Rice(Paddy-Hus)', 'Additive'),
#  ('Mangrulpeer-Gram', 'Multiplicative'),
#  ('Mangrulpeer-Sorgum(Jawar)', 'Additive'),
#  ('Mangrulpeer-Soybean', 'Multiplicative'),
#  ('Mangrulpeer-Wheat(Husked)', 'Multiplicative'),
#  ('Manmad-Bajri', 'Multiplicative'),
#  ('Manmad-Gram', 'Multiplicative'),
#  ('Manmad-Maize', 'Multiplicative'),
#  ('Manmad-Wheat(Husked)', 'Multiplicative'),
#  ('Manora-Soybean', 'Additive'),
#  ('Mohol-Maize', 'Multiplicative'),
#  ('Mohol-Sorgum(Jawar)', 'Multiplicative'),
#  ('Mohol-Wheat(Husked)', 'Multiplicative'),
#  ('Morshi-Gram', 'Multiplicative'),
#  ('Morshi-Sorgum(Jawar)', 'Multiplicative'),
#  ('Morshi-Soybean', 'Multiplicative'),
#  ('Morshi-Wheat(Husked)', 'Additive'),
#  ('Mul-Paddy-Unhusked', 'Additive'),
#  ('Mumbai-Arvi', 'Multiplicative'),
#  ('Mumbai-Bitter Gourd', 'Multiplicative'),
#  ('Mumbai-Bottle Gourd', 'Multiplicative'),
#  ('Mumbai-Brinjal', 'Multiplicative'),
#  ('Mumbai-Cabbage', 'Multiplicative'),
#  ('Mumbai-Capsicum', 'Multiplicative'),
#  ('Mumbai-Carrot', 'Multiplicative'),
#  ('Mumbai-Chikoo', 'Multiplicative'),
#  ('Mumbai-Cowpea', 'Additive'),
#  ('Mumbai-Cucumber', 'Additive'),
#  ('Mumbai-Curry Leaves', 'Additive'),
#  ('Mumbai-Elephant Root', 'Additive'),
#  ('Mumbai-Flower', 'Additive'),
#  ('Mumbai-Garlic', 'Multiplicative'),
#  ('Mumbai-Ginger (Dry)', 'Additive'),
#  ('Mumbai-Green Chilli', 'Multiplicative'),
#  ('Mumbai-Green Peas (Dry)', 'Multiplicative'),
#  ('Mumbai-Green-Peas', 'Additive'),
#  ('Mumbai-Guava', 'Multiplicative'),
#  ('Mumbai-Jaggery', 'Multiplicative'),
#  ('Mumbai-Ladies Finger', 'Multiplicative'),
#  ('Mumbai-Melon', 'Multiplicative'),
#  ('Mumbai-Mosambi', 'Additive'),
#  ('Mumbai-Papai', 'Additive'),
#  ('Mumbai-Pineapple', 'Multiplicative'),
#  ('Mumbai-Ridge Gourd', 'Multiplicative'),
#  ('Mumbai-Shevga', 'Additive'),
#  ('Mumbai-Small Gourd', 'Multiplicative'),
#  ('Mumbai-Snake Gourd', 'Multiplicative'),
#  ('Mumbai-Split Gram', 'Multiplicative'),
#  ('Mumbai-Split Lentil', 'Multiplicative'),
#  ('Mumbai-Squash Gourd', 'Multiplicative'),
#  ('Mumbai-Sweet Potato', 'Multiplicative'),
#  ('Mumbai-Tamarind', 'Additive'),
#  ('Murbad-Bitter Gourd', 'Additive'),
#  ('Murbad-Bottle Gourd', 'Additive'),
#  ('Murbad-Brinjal', 'Additive'),
#  ('Murbad-Ghosali(Bhaji)', 'Additive'),
#  ('Murbad-Ladies Finger', 'Additive'),
#  ('Murbad-Paddy-Unhusked', 'Multiplicative'),
#  ('Murbad-Tomato', 'Multiplicative'),
#  ('Murtizapur-Gram', 'Additive'),
#  ('Murtizapur-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Murtizapur-Soybean', 'Multiplicative'),
#  ('Murtizapur-Wheat(Husked)', 'Multiplicative'),
#  ('Nagbhid-Paddy-Unhusked', 'Multiplicative'),
#  ('Nagpur-Banana', 'Multiplicative'),
#  ('Nagpur-Beet Root', 'Multiplicative'),
#  ('Nagpur-Bottle Gourd', 'Multiplicative'),
#  ('Nagpur-Brinjal', 'Additive'),
#  ('Nagpur-Cabbage', 'Multiplicative'),
#  ('Nagpur-Capsicum', 'Multiplicative'),
#  ('Nagpur-Chikoo', 'Additive'),
#  ('Nagpur-Chillies(Red)', 'Multiplicative'),
#  ('Nagpur-Coriander  ', 'Additive'),
#  ('Nagpur-Cucumber', 'Additive'),
#  ('Nagpur-Flower', 'Multiplicative'),
#  ('Nagpur-Ginger (Fresh)', 'Multiplicative'),
#  ('Nagpur-Gram', 'Multiplicative'),
#  ('Nagpur-Grapes', 'Additive'),
#  ('Nagpur-Green Chilli', 'Multiplicative'),
#  ('Nagpur-Papai', 'Multiplicative'),
#  ('Nagpur-Pineapple', 'Multiplicative'),
#  ('Nagpur-Pomegranate', 'Multiplicative'),
#  ('Nagpur-Pumpkin', 'Multiplicative'),
#  ('Nagpur-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Nagpur-Small Gourd', 'Multiplicative'),
#  ('Nagpur-Soybean', 'Additive'),
#  ('Nagpur-Spinach', 'Multiplicative'),
#  ('Nagpur-Tomato', 'Multiplicative'),
#  ('Nagpur-Wheat(Husked)', 'Multiplicative'),
#  ('Nanded-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Nanded-Sorgum(Jawar)', 'Multiplicative'),
#  ('Nanded-Turmeric', 'Multiplicative'),
#  ('Nanded-Wheat(Husked)', 'Multiplicative'),
#  ('Nandura-Bajri', 'Additive'),
#  ('Nandura-Gram', 'Additive'),
#  ('Nandura-Maize', 'Multiplicative'),
#  ('Nandura-Sesamum', 'Multiplicative'),
#  ('Nandura-Sorgum(Jawar)', 'Additive'),
#  ('Nandura-Soybean', 'Additive'),
#  ('Nandura-Wheat(Husked)', 'Multiplicative'),
#  ('Nandurbar-Bajri', 'Multiplicative'),
#  ('Nandurbar-Cluster Bean', 'Multiplicative'),
#  ('Nandurbar-Gram', 'Multiplicative'),
#  ('Nandurbar-Maize', 'Multiplicative'),
#  ('Nandurbar-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Nandurbar-Sorgum(Jawar)', 'Multiplicative'),
#  ('Nandurbar-Soybean', 'Multiplicative'),
#  ('Nandurbar-Wheat(Husked)', 'Additive'),
#  ('Ner Parasopant-Soybean', 'Additive'),
#  ('Newasa-Wheat(Husked)', 'Multiplicative'),
#  ('Nira-Jaggery', 'Additive'),
#  ('Pandharpur-Banana', 'Multiplicative'),
#  ('Pandharpur-Brinjal', 'Additive'),
#  ('Pandharpur-Cabbage', 'Multiplicative'),
#  ('Pandharpur-Capsicum', 'Multiplicative'),
#  ('Pandharpur-Green Chilli', 'Multiplicative'),
#  ('Pandharpur-Onion', 'Multiplicative'),
#  ('Pandharpur-Pomegranate', 'Multiplicative'),
#  ('Pandharpur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Pandharpur-Tomato', 'Multiplicative'),
#  ('Parbhani-Gram', 'Additive'),
#  ('Parbhani-Soybean', 'Additive'),
#  ('Parbhani-Wheat(Husked)', 'Multiplicative'),
#  ('Parli-Vaijnath-Bajri', 'Multiplicative'),
#  ('Parli-Vaijnath-Gram', 'Multiplicative'),
#  ('Parli-Vaijnath-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Parli-Vaijnath-Sorgum(Jawar)', 'Multiplicative'),
#  ('Parli-Vaijnath-Soybean', 'Multiplicative'),
#  ('Partur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Partur-Wheat(Husked)', 'Additive'),
#  ('Patan-Brinjal', 'Additive'),
#  ('Patan-Cabbage', 'Additive'),
#  ('Patan-Flower', 'Multiplicative'),
#  ('Patan-Ginger (Fresh)', 'Multiplicative'),
#  ('Patan-Green Chilli', 'Multiplicative'),
#  ('Patan-Tomato', 'Multiplicative'),
#  ('Pathardi-Bajri', 'Additive'),
#  ('Pathardi-Onion', 'Multiplicative'),
#  ('Pathardi-Sorgum(Jawar)', 'Additive'),
#  ('Pathardi-Wheat(Husked)', 'Multiplicative'),
#  ('Pathari-Wheat(Husked)', 'Multiplicative'),
#  ('Patur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Patur-Soybean', 'Multiplicative'),
#  ('Patur-Wheat(Husked)', 'Multiplicative'),
#  ('Pavani-Paddy-Unhusked', 'Additive'),
#  ('Pen-Paddy-Unhusked', 'Multiplicative'),
#  ('Pen-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Pimpalgaon Basawant-Pomegranate', 'Multiplicative'),
#  ('Pune-Bajri', 'Additive'),
#  ('Pune-Beet Root', 'Additive'),
#  ('Pune-Bitter Gourd', 'Multiplicative'),
#  ('Pune-Bottle Gourd', 'Additive'),
#  ('Pune-Brinjal', 'Multiplicative'),
#  ('Pune-Cabbage', 'Multiplicative'),
#  ('Pune-Capsicum', 'Additive'),
#  ('Pune-Carrot', 'Multiplicative'),
#  ('Pune-Chavli (Shenga )', 'Additive'),
#  ('Pune-Cluster Bean', 'Multiplicative'),
#  ('Pune-Cucumber', 'Additive'),
#  ('Pune-Curry Leaves', 'Multiplicative'),
#  ('Pune-Elephant Root', 'Multiplicative'),
#  ('Pune-Flower', 'Multiplicative'),
#  ('Pune-Ghevda', 'Multiplicative'),
#  ('Pune-Ghosali(Bhaji)', 'Multiplicative'),
#  ('Pune-Ginger (Fresh)', 'Multiplicative'),
#  ('Pune-Gr.Nut Kernels', 'Multiplicative'),
#  ('Pune-Gram', 'Additive'),
#  ('Pune-Green Chilli', 'Additive'),
#  ('Pune-Green Peas (Dry)', 'Multiplicative'),
#  ('Pune-Green-Peas', 'Multiplicative'),
#  ('Pune-Ladies Finger', 'Multiplicative'),
#  ('Pune-Lentil', 'Multiplicative'),
#  ('Pune-Maize', 'Additive'),
#  ('Pune-Mango(Raw)', 'Multiplicative'),
#  ('Pune-Pavtta', 'Multiplicative'),
#  ('Pune-Pumpkin', 'Additive'),
#  ('Pune-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Pune-Ridge Gourd', 'Multiplicative'),
#  ('Pune-Shevga', 'Multiplicative'),
#  ('Pune-Small Gourd', 'Multiplicative'),
#  ('Pune-Snake Gourd', 'Multiplicative'),
#  ('Pune-Sorgum(Jawar)', 'Additive'),
#  ('Pune-Squash Gourd', 'Multiplicative'),
#  ('Pune-Sweet Potato', 'Additive'),
#  ('Pune-Tamarind', 'Additive'),
#  ('Pune-Tomato', 'Additive'),
#  ('Pune-Wal Bhaji', 'Multiplicative'),
#  ('Pune-Wal Papdi', 'Multiplicative'),
#  ('Pune-Walvad', 'Multiplicative'),
#  ('Pune-Wheat(Husked)', 'Multiplicative'),
#  ('Pune-Manjri-Bitter Gourd', 'Multiplicative'),
#  ('Pune-Manjri-Bottle Gourd', 'Additive'),
#  ('Pune-Manjri-Brinjal', 'Additive'),
#  ('Pune-Manjri-Chavli (Pala)', 'Multiplicative'),
#  ('Pune-Manjri-Cluster Bean', 'Additive'),
#  ('Pune-Manjri-Coriander  ', 'Multiplicative'),
#  ('Pune-Manjri-Cucumber', 'Additive'),
#  ('Pune-Manjri-Flower', 'Multiplicative'),
#  ('Pune-Manjri-Green Chilli', 'Multiplicative'),
#  ('Pune-Manjri-Kanda Pat', 'Multiplicative'),
#  ('Pune-Manjri-Ladies Finger', 'Additive'),
#  ('Pune-Manjri-Methi (Bhaji)', 'Multiplicative'),
#  ('Pune-Manjri-Raddish', 'Multiplicative'),
#  ('Pune-Manjri-Ridge Gourd', 'Multiplicative'),
#  ('Pune-Manjri-Shepu', 'Multiplicative'),
#  ('Pune-Manjri-Spinach', 'Multiplicative'),
#  ('Pune-Manjri-Tomato', 'Multiplicative'),
#  ('Pune-Manjri-Walvad', 'Multiplicative'),
#  ('Pune-Pimpri-Beet Root', 'Additive'),
#  ('Pune-Pimpri-Bitter Gourd', 'Additive'),
#  ('Pune-Pimpri-Bottle Gourd', 'Additive'),
#  ('Pune-Pimpri-Brinjal', 'Multiplicative'),
#  ('Pune-Pimpri-Cabbage', 'Additive'),
#  ('Pune-Pimpri-Cucumber', 'Multiplicative'),
#  ('Pune-Pimpri-Flower', 'Multiplicative'),
#  ('Pune-Pimpri-Ghevda', 'Multiplicative'),
#  ('Pune-Pimpri-Green Chilli', 'Multiplicative'),
#  ('Pune-Pimpri-Ladies Finger', 'Additive'),
#  ('Pune-Pimpri-Onion', 'Multiplicative'),
#  ('Pune-Pimpri-Tomato', 'Multiplicative'),
#  ('Rahata-Bajri', 'Multiplicative'),
#  ('Rahata-Bitter Gourd', 'Multiplicative'),
#  ('Rahata-Bottle Gourd', 'Multiplicative'),
#  ('Rahata-Brinjal', 'Additive'),
#  ('Rahata-Capsicum', 'Multiplicative'),
#  ('Rahata-Carrot', 'Additive'),
#  ('Rahata-Cucumber', 'Multiplicative'),
#  ('Rahata-Garlic', 'Multiplicative'),
#  ('Rahata-Ghevda', 'Additive'),
#  ('Rahata-Ginger (Fresh)', 'Multiplicative'),
#  ('Rahata-Gram', 'Additive'),
#  ('Rahata-Green Chilli', 'Additive'),
#  ('Rahata-Ladies Finger', 'Multiplicative'),
#  ('Rahata-Lemon', 'Multiplicative'),
#  ('Rahata-Maize', 'Additive'),
#  ('Rahata-Potato', 'Additive'),
#  ('Rahata-Shevga', 'Multiplicative'),
#  ('Rahata-Small Gourd', 'Additive'),
#  ('Rahata-Sorgum(Jawar)', 'Multiplicative'),
#  ('Rahata-Tomato', 'Multiplicative'),
#  ('Rahata-Wheat(Husked)', 'Multiplicative'),
#  ('Rahuri-Vambori-Bajri', 'Multiplicative'),
#  ('Rahuri-Vambori-Gram', 'Multiplicative'),
#  ('Rahuri-Vambori-Maize', 'Multiplicative'),
#  ('Rahuri-Vambori-Onion', 'Additive'),
#  ('Rahuri-Vambori-Sorgum(Jawar)', 'Multiplicative'),
#  ('Rahuri-Vambori-Soybean', 'Multiplicative'),
#  ('Rahuri-Vambori-Wheat(Husked)', 'Multiplicative'),
#  ('Ramtek-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Ramtek-Wheat(Husked)', 'Multiplicative'),
#  ('Ratanagari-Bitter Gourd', 'Additive'),
#  ('Ratanagari-Brinjal', 'Multiplicative'),
#  ('Ratanagari-Cabbage', 'Multiplicative'),
#  ('Ratanagari-Capsicum', 'Additive'),
#  ('Ratanagari-Cucumber', 'Multiplicative'),
#  ('Ratanagari-Flower', 'Multiplicative'),
#  ('Ratanagari-Ginger (Fresh)', 'Multiplicative'),
#  ('Ratanagari-Green Chilli', 'Multiplicative'),
#  ('Ratanagari-Green-Peas', 'Multiplicative'),
#  ('Ratanagari-Ladies Finger', 'Multiplicative'),
#  ('Ratanagari-Maize(Corn.)', 'Multiplicative'),
#  ('Ratanagari-Tomato', 'Additive'),
#  ('Raver-Gram', 'Additive'),
#  ('Raver-Maize', 'Multiplicative'),
#  ('Raver-Sorgum(Jawar)', 'Additive'),
#  ('Raver-Wheat(Husked)', 'Multiplicative'),
#  ('Risod-Gram', 'Additive'),
#  ('Roha-Paddy-Unhusked', 'Additive'),
#  ('Sailu-Sorgum(Jawar)', 'Multiplicative'),
#  ('Sailu-Soybean', 'Additive'),
#  ('Sangali-Bajri', 'Multiplicative'),
#  ('Sangali-Green Gram', 'Multiplicative'),
#  ('Sangali-Lentil', 'Multiplicative'),
#  ('Sangali-Sorgum(Jawar)', 'Additive'),
#  ('Sangali-Soybean', 'Multiplicative'),
#  ('Sangali-Wheat(Husked)', 'Additive'),
#  ('Sangali-Wheat(Unhusked)', 'Additive'),
#  ('Sangamner-Bajri', 'Multiplicative'),
#  ('Sangamner-Gram', 'Additive'),
#  ('Sangamner-Maize', 'Multiplicative'),
#  ('Sangamner-Pomegranate', 'Multiplicative'),
#  ('Sangamner-Sorgum(Jawar)', 'Multiplicative'),
#  ('Sangamner-Wheat(Husked)', 'Multiplicative'),
#  ('Sangola-Pomegranate', 'Multiplicative'),
#  ('Satara-Bitter Gourd', 'Multiplicative'),
#  ('Satara-Bottle Gourd', 'Multiplicative'),
#  ('Satara-Brinjal', 'Multiplicative'),
#  ('Satara-Cabbage', 'Multiplicative'),
#  ('Satara-Capsicum', 'Multiplicative'),
#  ('Satara-Cluster Bean', 'Multiplicative'),
#  ('Satara-Cucumber', 'Additive'),
#  ('Satara-Flower', 'Additive'),
#  ('Satara-Ginger (Fresh)', 'Additive'),
#  ('Satara-Green Chilli', 'Multiplicative'),
#  ('Satara-Ladies Finger', 'Multiplicative'),
#  ('Satara-Onion', 'Additive'),
#  ('Satara-Pavtta', 'Additive'),
#  ('Satara-Potato', 'Multiplicative'),
#  ('Satara-Tomato', 'Multiplicative'),
#  ('Savner-Gram', 'Additive'),
#  ('Savner-Pigeon Pea (Tur)', 'Additive'),
#  ('Savner-Soybean', 'Additive'),
#  ('Savner-Wheat(Husked)', 'Multiplicative'),
#  ('Shahada-Bajri', 'Additive'),
#  ('Shahada-Gram', 'Multiplicative'),
#  ('Shahada-Maize', 'Additive'),
#  ('Shahada-Sorgum(Jawar)', 'Additive'),
#  ('Shahada-Wheat(Husked)', 'Additive'),
#  ('Shahapur-Bitter Gourd', 'Multiplicative'),
#  ('Shahapur-Chavli (Shenga )', 'Multiplicative'),
#  ('Shahapur-Cucumber', 'Multiplicative'),
#  ('Shahapur-Ghosali(Bhaji)', 'Multiplicative'),
#  ('Shahapur-Ladies Finger', 'Additive'),
#  ('Shegaon-Black Gram', 'Multiplicative'),
#  ('Shegaon-Gram', 'Multiplicative'),
#  ('Shegaon-Green Gram', 'Multiplicative'),
#  ('Shegaon-Maize', 'Additive'),
#  ('Shegaon-Mustard', 'Multiplicative'),
#  ('Shegaon-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Shegaon-Sorgum(Jawar)', 'Multiplicative'),
#  ('Shegaon-Soybean', 'Multiplicative'),
#  ('Shegaon-Wheat(Husked)', 'Multiplicative'),
#  ('Shevgaon-Bajri', 'Multiplicative'),
#  ('Shevgaon-Gram', 'Multiplicative'),
#  ('Shevgaon-Sorgum(Jawar)', 'Additive'),
#  ('Shevgaon-Wheat(Husked)', 'Multiplicative'),
#  ('Shevgaon-Bodhegaon-Bajri', 'Multiplicative'),
#  ('Shevgaon-Bodhegaon-Sorgum(Jawar)', 'Additive'),
#  ('Shevgaon-Bodhegaon-Wheat(Husked)', 'Additive'),
#  ('Shirpur-Bajri', 'Multiplicative'),
#  ('Shirpur-Gram', 'Additive'),
#  ('Shirpur-Green Gram', 'Additive'),
#  ('Shirpur-Ground Nut Pods (Dry)', 'Multiplicative'),
#  ('Shirpur-Maize', 'Multiplicative'),
#  ('Shirpur-Onion', 'Multiplicative'),
#  ('Shirpur-Sorgum(Jawar)', 'Additive'),
#  ('Shirpur-Soybean', 'Multiplicative'),
#  ('Shirpur-Wheat(Husked)', 'Multiplicative'),
#  ('Shirur-Bajri', 'Additive'),
#  ('Shirur-Gram', 'Multiplicative'),
#  ('Shirur-Ground Nut Pods (Dry)', 'Additive'),
#  ('Shirur-Indian Bean', 'Multiplicative'),
#  ('Shirur-Maize', 'Additive'),
#  ('Shirur-Sorgum(Jawar)', 'Additive'),
#  ('Shirur-Wheat(Husked)', 'Multiplicative'),
#  ('Shrirampur-Bajri', 'Multiplicative'),
#  ('Shrirampur-Bottle Gourd', 'Multiplicative'),
#  ('Shrirampur-Brinjal', 'Multiplicative'),
#  ('Shrirampur-Cabbage', 'Additive'),
#  ('Shrirampur-Capsicum', 'Multiplicative'),
#  ('Shrirampur-Chikoo', 'Additive'),
#  ('Shrirampur-Cucumber', 'Additive'),
#  ('Shrirampur-Flower', 'Additive'),
#  ('Shrirampur-Garlic', 'Additive'),
#  ('Shrirampur-Ginger (Fresh)', 'Multiplicative'),
#  ('Shrirampur-Gram', 'Multiplicative'),
#  ('Shrirampur-Green Chilli', 'Multiplicative'),
#  ('Shrirampur-Ladies Finger', 'Multiplicative'),
#  ('Shrirampur-Lemon', 'Additive'),
#  ('Shrirampur-Maize', 'Additive'),
#  ('Shrirampur-Mosambi', 'Additive'),
#  ('Shrirampur-Papai', 'Multiplicative'),
#  ('Shrirampur-Pomegranate', 'Additive'),
#  ('Shrirampur-Potato', 'Additive'),
#  ('Shrirampur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Shrirampur-Tomato', 'Multiplicative'),
#  ('Shrirampur-Water Melon', 'Additive'),
#  ('Shrirampur-Wheat(Husked)', 'Additive'),
#  ('Sinner-Bajri', 'Multiplicative'),
#  ('Sinner-Gram', 'Additive'),
#  ('Sinner-Maize', 'Additive'),
#  ('Sinner-Sorgum(Jawar)', 'Multiplicative'),
#  ('Sinner-Wheat(Husked)', 'Multiplicative'),
#  ('Solapur-Banana', 'Multiplicative'),
#  ('Solapur-Bitter Gourd', 'Multiplicative'),
#  ('Solapur-Brinjal', 'Multiplicative'),
#  ('Solapur-Cabbage', 'Multiplicative'),
#  ('Solapur-Capsicum', 'Multiplicative'),
#  ('Solapur-Carrot', 'Multiplicative'),
#  ('Solapur-Chikoo', 'Multiplicative'),
#  ('Solapur-Cluster Bean', 'Multiplicative'),
#  ('Solapur-Cucumber', 'Additive'),
#  ('Solapur-Gram', 'Multiplicative'),
#  ('Solapur-Green Chilli', 'Multiplicative'),
#  ('Solapur-Green Peas (Dry)', 'Multiplicative'),
#  ('Solapur-Ladies Finger', 'Additive'),
#  ('Solapur-Lemon', 'Multiplicative'),
#  ('Solapur-Matki', 'Multiplicative'),
#  ('Solapur-Papai', 'Multiplicative'),
#  ('Solapur-Potato', 'Multiplicative'),
#  ('Solapur-Rice(Paddy-Hus)', 'Additive'),
#  ('Solapur-Ridge Gourd', 'Additive'),
#  ('Solapur-Sorgum(Jawar)', 'Additive'),
#  ('Solapur-Tomato', 'Multiplicative'),
#  ('Solapur-Wheat(Husked)', 'Additive'),
#  ('Telhara-Gram', 'Multiplicative'),
#  ('Telhara-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Telhara-Sorgum(Jawar)', 'Multiplicative'),
#  ('Telhara-Soybean', 'Multiplicative'),
#  ('Telhara-Wheat(Husked)', 'Additive'),
#  ('Tuljapur-Gram', 'Additive'),
#  ('Tuljapur-Sorgum(Jawar)', 'Multiplicative'),
#  ('Udgir-Gram', 'Multiplicative'),
#  ('Udgir-Soybean', 'Multiplicative'),
#  ('Umared-Gram', 'Multiplicative'),
#  ('Umared-Linseed', 'Multiplicative'),
#  ('Umared-Other Pulses', 'Multiplicative'),
#  ('Umared-Pigeon Pea (Tur)', 'Additive'),
#  ('Umared-Rice(Paddy-Hus)', 'Multiplicative'),
#  ('Umared-Sorgum(Jawar)', 'Additive'),
#  ('Umared-Soybean', 'Multiplicative'),
#  ('Umared-Wheat(Husked)', 'Multiplicative'),
#  ('Umarga-Bajri', 'Additive'),
#  ('Umarga-Gram', 'Multiplicative'),
#  ('Umarga-Sorgum(Jawar)', 'Additive'),
#  ('Umarga-Soybean', 'Multiplicative'),
#  ('Umarga-Sunflower', 'Multiplicative'),
#  ('Umarga-Wheat(Husked)', 'Multiplicative'),
#  ('Umarkhed-Soybean', 'Multiplicative'),
#  ('Umarkhed-Danki-Soybean', 'Multiplicative'),
#  ('Umarkhed-Danki-Wheat(Husked)', 'Multiplicative'),
#  ('Vadgaon Peth-Bitter Gourd', 'Multiplicative'),
#  ('Vadgaon Peth-Brinjal', 'Multiplicative'),
#  ('Vadgaon Peth-Cabbage', 'Multiplicative'),
#  ('Vadgaon Peth-Capsicum', 'Multiplicative'),
#  ('Vadgaon Peth-Flower', 'Multiplicative'),
#  ('Vadgaon Peth-Ladies Finger', 'Additive'),
#  ('Vadgaon Peth-Ridge Gourd', 'Additive'),
#  ('Vadgaon Peth-Tomato', 'Multiplicative'),
#  ('Vaduj-Gram', 'Multiplicative'),
#  ('Vaduj-Maize', 'Additive'),
#  ('Vaduj-Sorgum(Jawar)', 'Multiplicative'),
#  ('Vai-Bottle Gourd', 'Multiplicative'),
#  ('Vai-Brinjal', 'Multiplicative'),
#  ('Vai-Cabbage', 'Multiplicative'),
#  ('Vai-Cucumber', 'Additive'),
#  ('Vai-Flower', 'Additive'),
#  ('Vai-Ginger (Fresh)', 'Additive'),
#  ('Vai-Green Chilli', 'Multiplicative'),
#  ('Vai-Ladies Finger', 'Multiplicative'),
#  ('Vai-Pavata', 'Additive'),
#  ('Vai-Tomato', 'Multiplicative'),
#  ('Varud-Rajura Bazar-Gram', 'Multiplicative'),
#  ('Varud-Rajura Bazar-Sorgum(Jawar)', 'Additive'),
#  ('Varud-Rajura Bazar-Soybean', 'Multiplicative'),
#  ('Washim-Black Gram', 'Multiplicative'),
#  ('Washim-Gram', 'Multiplicative'),
#  ('Washim-Green Gram', 'Additive'),
#  ('Washim-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Washim-Sorgum(Jawar)', 'Additive'),
#  ('Washim-Wheat(Husked)', 'Multiplicative'),
#  ('Yeola-Bajri', 'Multiplicative'),
#  ('Yeola-Gram', 'Multiplicative'),
#  ('Yeola-Maize', 'Additive'),
#  ('Yeola-Wheat(Husked)', 'Additive'),
#  ('Yeotmal-Pigeon Pea (Tur)', 'Multiplicative'),
#  ('Yeotmal-Soybean', 'Additive')]

# %%
seasonality = pd.DataFrame(seasonality, columns = ['Cluster', 'Seasonality'])
seasonality.to_csv('Seasonality_type.csv', index = False)

# %%
s_dic = seasonality.set_index('Cluster').to_dict()['Seasonality']
monthly['deseasonalized_price'] = np.nan
df = pd.DataFrame()
for cluster in s_dic.keys():
    temp = check_seasonality(monthly[monthly['cluster'] == cluster], deseasonalize = True)
    df = pd.concat([df, temp])

# %%
df
# Out:
#                 APMC         Commodity                   cluster       date  \
# 6624         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-04-01
# 6625         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-04-01
# 6628         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-08-01
# 6629         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-08-01
# 6632         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2014-12-01
# 6633         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-12-01
# 6636         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-02-01
# 6637         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-02-01
# 6640         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-01-01
# 6641         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-01-01
# 6644         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-07-01
# 6645         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-07-01
# 6648         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-06-01
# 6649         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-06-01
# 6652         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-03-01
# 6653         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-03-01
# 6656         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-05-01
# 6657         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-05-01
# 6660         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2014-11-01
# 6661         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-11-01
# 6664         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2014-10-01
# 6665         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-10-01
# 6666         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-10-01
# 6670         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2014-09-01
# 6671         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2015-09-01
# 6672         Aamgaon    Paddy-Unhusked    Aamgaon-Paddy-Unhusked 2016-09-01
# 6676   Akhadabalapur           Soybean     Akhadabalapur-Soybean 2015-04-01
# 6677   Akhadabalapur           Soybean     Akhadabalapur-Soybean 2016-04-01
# 6685   Akhadabalapur           Soybean     Akhadabalapur-Soybean 2015-08-01
# 6686   Akhadabalapur           Soybean     Akhadabalapur-Soybean 2016-08-01
# ...              ...               ...                       ...        ...
# 21629        Yeotmal  Pigeon Pea (Tur)  Yeotmal-Pigeon Pea (Tur) 2016-10-01
# 21659        Yeotmal  Pigeon Pea (Tur)  Yeotmal-Pigeon Pea (Tur) 2014-09-01
# 21660        Yeotmal  Pigeon Pea (Tur)  Yeotmal-Pigeon Pea (Tur) 2015-09-01
# 21661        Yeotmal  Pigeon Pea (Tur)  Yeotmal-Pigeon Pea (Tur) 2016-09-01
# 21404        Yeotmal           Soybean           Yeotmal-Soybean 2015-04-01
# 21405        Yeotmal           Soybean           Yeotmal-Soybean 2016-04-01
# 21426        Yeotmal           Soybean           Yeotmal-Soybean 2015-08-01
# 21427        Yeotmal           Soybean           Yeotmal-Soybean 2016-08-01
# 21448        Yeotmal           Soybean           Yeotmal-Soybean 2014-12-01
# 21449        Yeotmal           Soybean           Yeotmal-Soybean 2015-12-01
# 21469        Yeotmal           Soybean           Yeotmal-Soybean 2015-02-01
# 21470        Yeotmal           Soybean           Yeotmal-Soybean 2016-02-01
# 21491        Yeotmal           Soybean           Yeotmal-Soybean 2015-01-01
# 21492        Yeotmal           Soybean           Yeotmal-Soybean 2016-01-01
# 21512        Yeotmal           Soybean           Yeotmal-Soybean 2015-07-01
# 21513        Yeotmal           Soybean           Yeotmal-Soybean 2016-07-01
# 21534        Yeotmal           Soybean           Yeotmal-Soybean 2015-06-01
# 21535        Yeotmal           Soybean           Yeotmal-Soybean 2016-06-01
# 21556        Yeotmal           Soybean           Yeotmal-Soybean 2015-03-01
# 21557        Yeotmal           Soybean           Yeotmal-Soybean 2016-03-01
# 21578        Yeotmal           Soybean           Yeotmal-Soybean 2015-05-01
# 21579        Yeotmal           Soybean           Yeotmal-Soybean 2016-05-01
# 21599        Yeotmal           Soybean           Yeotmal-Soybean 2014-11-01
# 21600        Yeotmal           Soybean           Yeotmal-Soybean 2015-11-01
# 21630        Yeotmal           Soybean           Yeotmal-Soybean 2014-10-01
# 21631        Yeotmal           Soybean           Yeotmal-Soybean 2015-10-01
# 21632        Yeotmal           Soybean           Yeotmal-Soybean 2016-10-01
# 21662        Yeotmal           Soybean           Yeotmal-Soybean 2014-09-01
# 21663        Yeotmal           Soybean           Yeotmal-Soybean 2015-09-01
# 21664        Yeotmal           Soybean           Yeotmal-Soybean 2016-09-01
#
#        modal_price  deseasonalize_price
# 6624          1412          1539.551920
# 6625          1657          1693.188631
# 6628          1562          1524.016891
# 6629          1667          1501.760841
# 6632          1518          1576.033672
# 6633          1564          1523.967698
# 6636          1505          1431.565103
# 6637          1558          1411.914442
# 6640          1533          1476.385097
# 6641          1523          1478.489326
# 6644          1510          1479.974665
# 6645          1693          1481.748819
# 6648          1339          1492.765079
# 6649          1604          1511.703143
# 6652          1419          1529.073350
# 6653          1633          1547.268746
# 6656          1402          1565.752957
# 6657          1578          1577.635664
# 6660          1507          1647.460051
# 6661          1512          1656.899597
# 6664          1670          1661.723026
# 6665          1491          1771.095504
# 6666          1445          1659.335833
# 6670          1744          1581.354213
# 6671          1691          1498.061702
# 6672          1697          1465.064414
# 6676          3290          4070.668403
# 6677          3638          2788.960069
# 6685          3278          3190.335069
# 6686          3594          3162.376736
# ...            ...                  ...
# 21629         6111          8773.122211
# 21659         4599          4970.457575
# 21660         8752          5969.279143
# 21661         6476          5137.950849
# 21404         3527          3511.538194
# 21405         3857          3108.246528
# 21426         3240          3146.288194
# 21427         3282          3168.288194
# 21448         3163          3178.496528
# 21449         3551          3144.746528
# 21469         3162          3272.100694
# 21470         3599          3280.559028
# 21491         3176          3371.329861
# 21492         3569          3404.246528
# 21512         3436          3436.788194
# 21513         3640          3471.371528
# 21534         3496          3504.538194
# 21535         3657          3533.246528
# 21556         3167          3548.288194
# 21557         3526          3556.288194
# 21578         3670          3571.496528
# 21579         3701          3581.746528
# 21599         3162          3631.100694
# 21600         3564          3610.559028
# 21630         3070          3402.329861
# 21631         3495          3565.246528
# 21632         2781          3640.788194
# 21662         3225          3513.371528
# 21663         3218          3510.538194
# 21664         3224          2819.246528
#
# [21665 rows x 6 columns]

# %%
df.to_csv('Deseasonalized_price.csv', index = False)
